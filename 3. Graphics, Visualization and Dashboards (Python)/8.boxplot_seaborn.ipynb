# %%
import pandas as pd
import seaborn as srn

# %%
base = pd.read_csv('./data/trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Visualization of a boxplot
srn.boxplot(data=base.Volume, orient='v').set_title('Trees')
# Out:
# Text(0.5, 1.0, 'Trees')

# %%
# Viewing multiple boxplots on the same image
srn.boxplot(data = base)
# Out:
# <Axes: >
